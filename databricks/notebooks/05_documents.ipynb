# %% [markdown]
# # `docinfo` / `doclinks` / `vw_rfqvendor_documents` — attached documents
#
# Unity Catalog: `ingestion_framework_test.bid_data_exploration.docinfo`, `ingestion_framework_test.bid_data_exploration.doclinks`, `ingestion_framework_test.bid_data_exploration.vw_rfqvendor_documents`
#
# Expected: `docinfo` describes each attached file (name, type, maybe a storage pointer); `doclinks` connects a document to the RFQ/vendor record it belongs to; `vw_rfqvendor_documents` is a pre-built view joining the two. This is the real-data equivalent of the document-selection/curation step built for the sample data — worth checking whether a stored file path or a blob is actually retrievable from here.

# %% [markdown]
# ## Run 1 — initial exploration ✅ *(run in Databricks — awaiting results to document findings)*

# %% [markdown]
# ## `docinfo`

# %%
# %sql
DESCRIBE TABLE ingestion_framework_test.bid_data_exploration.docinfo

# %%
# %sql
SELECT COUNT(*) AS row_count FROM ingestion_framework_test.bid_data_exploration.docinfo

# %%
# %sql
SELECT * FROM ingestion_framework_test.bid_data_exploration.docinfo LIMIT 20

# %% [markdown]
# ## `doclinks`

# %%
# %sql
DESCRIBE TABLE ingestion_framework_test.bid_data_exploration.doclinks

# %%
# %sql
SELECT COUNT(*) AS row_count FROM ingestion_framework_test.bid_data_exploration.doclinks

# %%
# %sql
SELECT * FROM ingestion_framework_test.bid_data_exploration.doclinks LIMIT 20

# %% [markdown]
# ## `vw_rfqvendor_documents`

# %%
# %sql
DESCRIBE TABLE ingestion_framework_test.bid_data_exploration.vw_rfqvendor_documents

# %%
# %sql
SELECT COUNT(*) AS row_count FROM ingestion_framework_test.bid_data_exploration.vw_rfqvendor_documents

# %%
# %sql
SELECT * FROM ingestion_framework_test.bid_data_exploration.vw_rfqvendor_documents LIMIT 20

# %% [markdown]
# **Observations:**
# - _(fill in: is the actual file content reachable from here or just metadata, how a document maps to "bidder's official submission" vs. cover letters/certificates the way water's sample data mixed them, whether the view already does the curation join we'd otherwise write by hand)_
